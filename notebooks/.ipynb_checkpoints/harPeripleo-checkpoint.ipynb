# %% [markdown]
# # R Scripts to obtain enhanced Historic England Heritage at Risk Data
#
# This Jupyter notebook explains step by step how to get enhanced data from Historic England and the UK Gov Planning department to create the basis of the
# [Peripleo demo visualisation](https://heritage-at-risk.museologi.st) which builds on software created for the AHRC funded Locating a National Collection.
#
# This notebook takes data from CSV files, scrapes data from the web, combines it and then creates data ready to go into OpenRefine, before being transformed
# using NodeJS into Linked Places GeoJson.

# %% [markdown]
# # Obtain raw Heritage at Risk dataset
#
# First, we need to obtain the raw dataset that we want to use to replicate the processes taken to get to the [Peripleo visualisation](https://heritage-at-risk.museologi.st) and then use to start playing with data sources. This will not download the entire dataset of over 380,000 records from the feature server to enable this to run in a timely manner. The code explains how to do this for the entire data set.

# %%
# Download data from the Digital Planning page in csv format
library(readr)
rawdata <- read.csv('https://files.planning.data.gov.uk/dataset/heritage-at-risk.csv')
# Check the data you downloaded for structure
head(rawdata)
message(This gives you a dataset of 20 columns)
# Out:
#   dataset          end.date entity  entry.date geojson
# 1 heritage-at-risk NA       7500000 2024-09-26 NA
# 2 heritage-at-risk NA       7500001 2021-05-27 NA
# 3 heritage-at-risk NA       7500002 2024-09-26 NA
# 4 heritage-at-risk NA       7500003 2024-09-26 NA
# 5 heritage-at-risk NA       7500004 2024-09-26 NA
# 6 heritage-at-risk NA       7500005 2024-09-26 NA
#   geometry
# 1 MULTIPOLYGON (((-2.140406 52.691736,-2.140134 52.691751,-2.140105 52.691766,-2.140096 52.691800,-2.140079 52.692048,-2.140027 52.693374,-2.140035 52.693526,-2.140074 52.693677,-2.140109 52.693717,-2.140151 52.693742,-2.140207 52.693759,-2.140290 52.693770,-2.140513 52.693778,-2.141410 52.693796,-2.142850 52.693839,-2.143188 52.693857,-2.143404 52.693834,-2.143436 52.693819,-2.143453 52.693787,-2.143460 52.693738,-2.143433 52.691810,-2.143429 52.691754,-2.143417 52.691719,-2.143397 52.691694,-2.143376 52.691681,-2.143223 52.691662,-2.142031 52.691719,-2.141295 52.691711,-2.140406 52.691736)))
# 2 MULTIPOLYGON (((-3.529071 51.050513,-3.528912 51.050517,-3.528974 51.050646,-3.529731 51.050616,-3.529786 51.050423,-3.529854 51.050251,-3.530052 51.049873,-3.529864 51.049878,-3.529870 51.049916,-3.529745 51.049922,-3.529747 51.049945,-3.529552 51.049950,-3.529556 51.050001,-3.529418 51.050007,-3.529419 51.050030,-3.529363 51.050032,-3.529360 51.050007,-3.529231 51.050012,-3.529216 51.049849,-3.528877 51.049839,-3.528887 51.050269,-3.528870 51.050385,-3.529127 51.050382,-3.529126 51.050454,-3.529069 51.050454,-3.529071 51.050513)))
# 3 MULTIPOLYGON (((-2.861665 52.670295,-2.861330 52.670484,-2.861162 52.670614,-2.861089 52.670697,-2.861085 52.670777,-2.861138 52.670863,-2.861216 52.670948,-2.861323 52.671037,-2.861628 52.671269,-2.861980 52.671505,-2.862035 52.671528,-2.862105 52.671522,-2.862193 52.671488,-2.862409 52.671378,-2.862512 52.671317,-2.863067 52.671038,-2.863099 52.671008,-2.863061 52.670973,-2.862911 52.670876,-2.862707 52.670778,-2.862003 52.670305,-2.861851 52.670193,-2.861665 52.670295)))
# 4 MULTIPOLYGON (((-2.702104 52.619080,-2.703156 52.619377,-2.703886 52.618757,-2.703751 52.618281,-2.703742 52.618212,-2.703771 52.618081,-2.703439 52.617900,-2.702104 52.619080)))
# 5 MULTIPOLYGON (((-1.125435 51.602194,-1.125322 51.602193,-1.125441 51.602482,-1.125436 51.602755,-1.125472 51.602849,-1.125620 51.602967,-1.125668 51.603085,-1.125701 51.603295,-1.125677 51.603808,-1.126543 51.603805,-1.126994 51.603783,-1.127204 51.603766,-1.127649 51.603683,-1.128086 51.603493,-1.128235 51.603340,-1.128406 51.603031,-1.128530 51.602127,-1.128583 51.601409,-1.128317 51.601440,-1.127538 51.601463,-1.127228 51.601365,-1.127150 51.601182,-1.126602 51.601148,-1.126499 51.601128,-1.126446 51.601098,-1.126423 51.601058,-1.126392 51.600955,-1.126275 51.600956,-1.126287 51.601070,-1.126210 51.601077,-1.126240 51.601209,-1.125755 51.601297,-1.125462 51.601338,-1.125457 51.601407,-1.124810 51.601430,-1.124791 51.601828,-1.124930 51.601829,-1.125139 51.601807,-1.125225 51.601773,-1.125293 51.601720,-1.125359 51.601652,-1.125447 51.601586,-1.125435 51.602194)),((-1.127917 51.598020,-1.127969 51.598130,-1.127984 51.598853,-1.127987 51.599736,-1.127780 51.599771,-1.127711 51.600820,-1.128375 51.600852,-1.128644 51.600857,-1.128829 51.599192,-1.128922 51.598586,-1.128943 51.598346,-1.128936 51.598153,-1.128888 51.598091,-1.127867 51.597914,-1.127917 51.598020)))
# 6 MULTIPOLYGON (((-1.542041 51.746577,-1.541330 51.747420,-1.541002 51.747907,-1.540604 51.748604,-1.540221 51.749196,-1.539946 51.749482,-1.540739 51.749842,-1.544506 51.748465,-1.543543 51.746731,-1.543425 51.746539,-1.543276 51.746327,-1.543081 51.746086,-1.542896 51.745886,-1.542718 51.745712,-1.542041 51.746577)))
#   name
# 1 Roman fort west of Eaton House
# 2 Barlinch Priory
# 3 Roman villa 150 yards (140 metres) south east of Lea Hall
# 4 Abutment of Roman Bridge at Radnor Bridge
# 5 Defences to the Saxon town [within Bull and Kine Croft]
# 6 Rectangular enclosures 1100yds (1010m) north west of Mount Owen Farm
#   organisation.entity point                      prefix           reference
# 1 16                  POINT(-2.141775 52.692762) heritage-at-risk 1006098
# 2 16                  POINT(-3.529384 51.050242) heritage-at-risk 1006213
# 3 16                  POINT(-2.862003 52.670884) heritage-at-risk 1006246
# 4 16                  POINT(-2.703145 52.618715) heritage-at-risk 1006280
# 5 16                  POINT(-1.127250 51.601647) heritage-at-risk 1006329
# 6 16                  POINT(-1.542321 51.748031) heritage-at-risk 1006348
#   start.date typology  categories
# 1 NA         geography NA
# 2 NA         geography NA
# 3 NA         geography NA
# 4 NA         geography NA
# 5 NA         geography NA
# 6 NA         geography NA
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35747
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/42043
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/41990
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/47933
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35923
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/30561
#   geography heritage.at.risk legislation notes organisation
# 1 NA        NA               NA          NA    NA
# 2 NA        NA               NA          NA    NA
# 3 NA        NA               NA          NA    NA
# 4 NA        NA               NA          NA    NA
# 5 NA        NA               NA          NA    NA
# 6 NA        NA               NA          NA    NA

# %% [markdown]
# You will see above that the raw data set has 20 columns of data. We probably don't need all of these right now. So let's remove the ones we do not need. You will see there is a geometry file for the GeoJSON outline, we could get the centre of this, but I wanted to show how to convert British National Grid to LatLon coordinates so we drop this too.

# %%
# Define columns to drop
drops <- c("organisation.entity","prefix", "categories", "legislation", "notes", "geometry", "geojson")
# Drop the columns
rawDataCols <-rawdata[ , !(names(rawdata) %in% drops)]
# Rename reference column
names(rawDataCols)[names(rawDataCols) == "reference"] <- "ListEntry"

# Test your data again
head(rawDataCols)
write_csv(rawDataCols, 'HAR.csv')
message('This produces a 13 column data set of HAR data')
# Out:
#   dataset          end.date entity  entry.date
# 1 heritage-at-risk NA       7500000 2024-09-26
# 2 heritage-at-risk NA       7500001 2021-05-27
# 3 heritage-at-risk NA       7500002 2024-09-26
# 4 heritage-at-risk NA       7500003 2024-09-26
# 5 heritage-at-risk NA       7500004 2024-09-26
# 6 heritage-at-risk NA       7500005 2024-09-26
#   name
# 1 Roman fort west of Eaton House
# 2 Barlinch Priory
# 3 Roman villa 150 yards (140 metres) south east of Lea Hall
# 4 Abutment of Roman Bridge at Radnor Bridge
# 5 Defences to the Saxon town [within Bull and Kine Croft]
# 6 Rectangular enclosures 1100yds (1010m) north west of Mount Owen Farm
#   point                      ListEntry start.date typology
# 1 POINT(-2.141775 52.692762) 1006098   NA         geography
# 2 POINT(-3.529384 51.050242) 1006213   NA         geography
# 3 POINT(-2.862003 52.670884) 1006246   NA         geography
# 4 POINT(-2.703145 52.618715) 1006280   NA         geography
# 5 POINT(-1.127250 51.601647) 1006329   NA         geography
# 6 POINT(-1.542321 51.748031) 1006348   NA         geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35747
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/42043
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/41990
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/47933
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35923
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/30561
#   geography heritage.at.risk organisation
# 1 NA        NA               NA
# 2 NA        NA               NA
# 3 NA        NA               NA
# 4 NA        NA               NA
# 5 NA        NA               NA
# 6 NA        NA               NA
# This produces a 13 column data set of HAR data

# %% [markdown]
# We now have a slightly modified set of data. 20 columns has been reduced to 13.
# We are now going to get some extra data from the NHLE resources. Have a look at the [ArcView Feature Server](https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/ArcGIS/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer) page to work out what to download. There is an array of data layers with corresponding integers - eg 0, 6 etc and the server is **ZOdPfBS3aqqDYPUQ**. You will want all these data and all the fields, so wild card away.

# %%
# Load the jsonlite library
library(jsonlite)
# Get the json response from the ARCVIEW server
# To get the parameters required read the API manual https://developers.arcgis.com/rest/services-reference/enterprise/query-feature-service/
# The id for the server is ZOdPfBS3aqqDYPUQ
# The FeatureServer is 0
# The dataset for NHLE points is National_Heritage_List_for_England_NHLE_v02_VIEW
countNHLE <- fromJSON('https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/ArcGIS/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&objectIds=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&relationParam=&returnGeodetic=false&outFields=*&returnGeometry=true&returnEnvelope=false&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&defaultSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=true&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&collation=&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=200&returnZ=false&returnM=false&returnTrueCurves=true&returnExceededLimitFeatures=false&quantizationParameters=&sqlFormat=none&f=json&token=')
# Get the count
totalNHLE <- countNHLE$count[1]
# Print this value
message(paste0('The total number of NHLE listed buildings equals: ', totalNHLE))
# We are going to get 1000 records at a time
recordsToReturn <- 50
# We are going to paginate this response
pagination <- ceiling(totalNHLE/recordsToReturn)
# Set the pagination limit low for this demo script 
pagination <- 20
# Out:
# The total number of NHLE listed buildings equals: 379557

# %% [markdown]
# ## Download the NHLE listed buildings data
#
# We are now going to download data from the NHLE listed buildings data feature layer. This is layer 0.

# %%
# Obtain data from the ArcGIS feature server
# The id for the server is ZOdPfBS3aqqDYPUQ
# The FeatureServer is 0
# The dataset for NHLE points is National_Heritage_List_for_England_NHLE_v02_VIEW
url <- paste0("https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=", recordsToReturn)
json <- fromJSON(url)
data <- json$features$attributes
# Decide which columns to keep
keeps <- c("ListEntry","Name","Grade","hyperlink","NGR","Easting","Northing")
data <- data[,(names(data) %in% keeps)]

# Now paginate through the data set
for (i in seq(from=(1 * recordsToReturn), to=(pagination*recordsToReturn), by=recordsToReturn)){
  urlDownload <- paste(url, '&resultOffset=', i, sep='')
  print(urlDownload)
  pagedJson <- fromJSON(urlDownload)
  records <- pagedJson$features$attributes
  records <- records[,(names(records) %in% keeps)]
  data <-rbind(data,records)
  # Add a snooze so we don't get blocked easily
  Sys.sleep(1.0)
}
head(data)

message('This produces a data frame that is 7 column data set') 

# Check if packages exist and if not install them for use
packages <- c("sf", "utils")
any_not_installed <- !all(packages %in% installed.packages()[, "Package"])
if (any_not_installed) {
  # Code to execute if at least one package is not installed
  message("At least one of the packages is not installed.")
  # Install missing packages
  missing_packages <- packages[!(packages %in% installed.packages()[, "Package"])]
  if (length(missing_packages) > 0) {
    install.packages(missing_packages)
  }
} 

library(utils)
library(sf)

# Subset the point data
pointData <- subset(data, select = c("Easting","Northing"))

## Create coordinates variable
coordsCast <- cbind(Easting = as.numeric(as.character(pointData$Easting)),
                Northing = as.numeric(as.character(pointData$Northing)))

# Create an sf object with BNG coordinates
bng_coords <- st_as_sf(data.frame(coordsCast), 
                     coords = c("Easting", "Northing"), 
                     crs = 27700) 

# Transform to WGS84 (EPSG:4326)
wgs84_coords <- st_transform(bng_coords, 4326)

# Extract latitude and longitude and append to data
data$lat <- st_coordinates(wgs84_coords)[, "Y"]
data$lon <- st_coordinates(wgs84_coords)[, "X"]

# Print the head rows of the new data frame
head(data)
message('This produces a data frame that is 9 column data set') 

# Write to a csv file 
write_csv(data, 'NHLE.csv')
# Out:
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=50"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=100"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=150"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=200"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=250"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=300"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=350"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=400"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=450"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=500"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=550"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=600"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=650"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=700"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=750"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=800"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=850"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=900"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=950"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/0/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=50&resultOffset=1000"
#   ListEntry Name                                            Grade
# 1 1021466   20 and 20A Whitbourne Springs                   II
# 2 1021467   TENNIS CORNER FARMHOUSE WITH GRANARY AND STABLE II
# 3 1021468   CHALCOT HOUSE                                   II*
# 4 1021469   FIVE LORDS FARMHOUSE                            II
# 5 1021470   PENLEIGH MILL                                   II
# 6 1021471   PENLEIGH HOUSE                                  II
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1021466
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1021467
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1021468
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1021469
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1021470
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1021471
#   NGR            Easting Northing
# 1 ST8338544428   383389  144430
# 2 ST 82839 50851 382839  150851
# 3 ST 84294 48824 384294  148824
# 4 ST 82772 50187 382772  150187
# 5 ST 85722 50467 385722  150467
# 6 ST 85622 50828 385622  150828
# This produces a data frame that is 7 column data set
#   ListEntry Name                                            Grade
# 1 1021466   20 and 20A Whitbourne Springs                   II
# 2 1021467   TENNIS CORNER FARMHOUSE WITH GRANARY AND STABLE II
# 3 1021468   CHALCOT HOUSE                                   II*
# 4 1021469   FIVE LORDS FARMHOUSE                            II
# 5 1021470   PENLEIGH MILL                                   II
# 6 1021471   PENLEIGH HOUSE                                  II
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1021466
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1021467
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1021468
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1021469
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1021470
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1021471
#   NGR            Easting Northing lat      lon
# 1 ST8338544428   383389  144430   51.19884 -2.239118
# 2 ST 82839 50851 382839  150851   51.25656 -2.247300
# 3 ST 84294 48824 384294  148824   51.23838 -2.226360
# 4 ST 82772 50187 382772  150187   51.25059 -2.248227
# 5 ST 85722 50467 385722  150467   51.25319 -2.205971
# 6 ST 85622 50828 385622  150828   51.25643 -2.207419
# This produces a data frame that is 9 column data set

# %% [markdown]
# We are now going to do this for the scheduled monuments, conservation and battlefields listed data sets as well. Same drill, similar outcome.

# %% [markdown]
# ## Download the NHLE Scheduled Monument Data
#
# Now to repeat the steps above, but for a different set of data, this time for scheduled monument data. This is feature server layer 6.

# %%
# Load the jsonlite library
library(jsonlite)
# Get the json response from the ARCVIEW server
# To get the parameters required read the API manual https://developers.arcgis.com/rest/services-reference/enterprise/query-feature-service/
# The id for the server is ZOdPfBS3aqqDYPUQ
# The FeatureServer is 6
# The dataset for NHLE points is National_Heritage_List_for_England_NHLE_v02_VIEW
countNHLE_Monuments <- fromJSON('https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/ArcGIS/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&objectIds=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&relationParam=&returnGeodetic=false&outFields=*&returnGeometry=true&returnEnvelope=false&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&defaultSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=true&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&collation=&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=200&returnZ=false&returnM=false&returnTrueCurves=true&returnExceededLimitFeatures=false&quantizationParameters=&sqlFormat=none&f=json&token=')
# Get the count
totalScheduled <- countNHLE_Monuments$count[1]
# Print this value
message(totalScheduled)
# We are going to get 1000 records at a time
recordsToReturn <- 10
# We are going to paginate this response
pagination <- ceiling(totalScheduled/recordsToReturn)

# Set the pagination to 10 for this demo
pagination <- 10

# Obtain data from the ArcGIS feature server - Scheduled monuments are layer 6
url <- paste0("https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=", recordsToReturn)
json <- fromJSON(url)
data <- json$features$attributes
# Decide which columns to keep
keeps <- c("ListEntry","Name","Grade","hyperlink","NGR","Easting","Northing")
data <- data[,(names(data) %in% keeps)]

# Now paginate through the data set
for (i in seq(from=(1 * recordsToReturn), to=(pagination*recordsToReturn), by=recordsToReturn)){
  urlDownload <- paste(url, '&resultOffset=', i, sep='')
  print(urlDownload)
  pagedJson <- fromJSON(urlDownload)
  records <- pagedJson$features$attributes
  records <- records[,(names(records) %in% keeps)]
  data <-rbind(data,records)
  # Add a snooze so we don't get blocked easily
  Sys.sleep(1.0)
}
data$grade <- NA
head(data)

message('This produces a data frame that is 7 column data set') 

# Check if packages exist and if not install them for use
packages <- c("sf", "utils")
any_not_installed <- !all(packages %in% installed.packages()[, "Package"])
if (any_not_installed) {
  # Code to execute if at least one package is not installed
  message("At least one of the packages is not installed.")
  # Install missing packages
  missing_packages <- packages[!(packages %in% installed.packages()[, "Package"])]
  if (length(missing_packages) > 0) {
    install.packages(missing_packages)
  }
} 
library(utils)
library(sf)

# Subset the point data
pointData <- subset(data, select = c("Easting","Northing"))

## Create coordinates variable
coordsCast <- cbind(Easting = as.numeric(as.character(pointData$Easting)),
                Northing = as.numeric(as.character(pointData$Northing)))

# Create an sf object with BNG coordinates
bng_coords <- st_as_sf(data.frame(coordsCast), 
                     coords = c("Easting", "Northing"), 
                     crs = 27700) 

# Transform to WGS84 (EPSG:4326)
wgs84_coords <- st_transform(bng_coords, 4326)

# Extract latitude and longitude and append to data
data$lat <- st_coordinates(wgs84_coords)[, "Y"]
data$lon <- st_coordinates(wgs84_coords)[, "X"]

# Print the head rows of the new data frame
head(data)
message('This produces a data frame that is 9 column data set') 

# Write to a csv file 
write_csv(data, 'ScheduledMonuments.csv')
# Out:
# 19990
# [1] 10
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=10"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=20"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=30"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=40"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=50"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=60"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=70"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=80"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=90"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/6/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=100"
#   ListEntry
# 1 1001718
# 2 1001719
# 3 1001720
# 4 1001721
# 5 1001722
# 6 1001723
#   Name
# 1 Mound S of Woodbrook
# 2 Castle Twts
# 3 Lyonshall Castle
# 4 Mound 1200yds (1100m) NNE of the Church
# 5 Limebrook Priory
# 6 Two bowl barrows, one 220m east of Lower Longbeak and the other 320m east of Higher Longbeak
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1001718
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1001719
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1001720
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1001721
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1001722
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1001723
#   NGR                            Easting Northing grade
# 1 SO 30447 54456                 330447  254456   NA
# 2 SO 27703 55474                 327703  255474   NA
# 3 SO 33165 56319                 333165  256319   NA
# 4 SO 37237 68101                 337237  268101   NA
# 5 SO 37411 66071                 337411  266071   NA
# 6 SS 19954 03896, SS 19871 03235 219871  103235   NA
# This produces a data frame that is 7 column data set
#   ListEntry
# 1 1001718
# 2 1001719
# 3 1001720
# 4 1001721
# 5 1001722
# 6 1001723
#   Name
# 1 Mound S of Woodbrook
# 2 Castle Twts
# 3 Lyonshall Castle
# 4 Mound 1200yds (1100m) NNE of the Church
# 5 Limebrook Priory
# 6 Two bowl barrows, one 220m east of Lower Longbeak and the other 320m east of Higher Longbeak
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1001718
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1001719
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1001720
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1001721
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1001722
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1001723
#   NGR                            Easting Northing grade lat      lon
# 1 SO 30447 54456                 330447  254456   NA    52.18395 -3.018721
# 2 SO 27703 55474                 327703  255474   NA    52.19274 -3.059066
# 3 SO 33165 56319                 333165  256319   NA    52.20103 -2.979341
# 4 SO 37237 68101                 337237  268101   NA    52.30742 -2.921963
# 5 SO 37411 66071                 337411  266071   NA    52.28919 -2.919033
# 6 SS 19954 03896, SS 19871 03235 219871  103235   NA    50.80061 -4.557574
# This produces a data frame that is 9 column data set

# %% [markdown]
# # Download Registered Parks and Gardens
#
# We now download registered parks and gardens data, the feature layer is 7.

# %%
# Load the jsonlite library
library(jsonlite)
# Get the json response from the ARCVIEW server
# To get the parameters required read the API manual https://developers.arcgis.com/rest/services-reference/enterprise/query-feature-service/
# The id for the server is ZOdPfBS3aqqDYPUQ
# The FeatureServer is 7
# The dataset for NHLE points is National_Heritage_List_for_England_NHLE_v02_VIEW
countNHLEParks <- fromJSON('https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/ArcGIS/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&objectIds=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&relationParam=&returnGeodetic=false&outFields=*&returnGeometry=true&returnEnvelope=false&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&defaultSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=true&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&collation=&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=200&returnZ=false&returnM=false&returnTrueCurves=true&returnExceededLimitFeatures=false&quantizationParameters=&sqlFormat=none&f=json&token=')
# Get the count
totalParks <- countNHLEParks$count[1]
# Print this value
head(totalParks)
# We are going to get 10 records at a time
recordsToReturn <- 10
# We are going to paginate this response
pagination <- ceiling(totalParks/recordsToReturn)
# Set the pagination level to 10 for this demo.
pagination <- 10
# Obtain data from the ArcGIS feature server 
url <- paste0("https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=", recordsToReturn)
json <- fromJSON(url)
data <- json$features$attributes
# Decide which columns to keep
keeps <- c("ListEntry","Name","Grade","hyperlink","NGR","Easting","Northing")
data <- data[,(names(data) %in% keeps)]

# Now paginate through the data set
for (i in seq(from=(1 * recordsToReturn), to=(pagination*recordsToReturn), by=recordsToReturn)){
  urlDownload <- paste(url, '&resultOffset=', i, sep='')
  print(urlDownload)
  pagedJson <- fromJSON(urlDownload)
  records <- pagedJson$features$attributes
  records <- records[,(names(records) %in% keeps)]
  data <-rbind(data,records)
  # Add a snooze so we don't get blocked easily
  Sys.sleep(1.0)
}
head(data)

message('This produces a data frame that is 7 column data set') 

# Check if packages exist and if not install them for use
packages <- c("sf", "utils")
any_not_installed <- !all(packages %in% installed.packages()[, "Package"])
if (any_not_installed) {
  # Code to execute if at least one package is not installed
  message("At least one of the packages is not installed.")
  # Install missing packages
  missing_packages <- packages[!(packages %in% installed.packages()[, "Package"])]
  if (length(missing_packages) > 0) {
    install.packages(missing_packages)
  }
} 
library(utils)
library(sf)

# Subset the point data
pointData <- subset(data, select = c("Easting","Northing"))

## Create coordinates variable
coordsCast <- cbind(Easting = as.numeric(as.character(pointData$Easting)),
                Northing = as.numeric(as.character(pointData$Northing)))

# Create an sf object with BNG coordinates
bng_coords <- st_as_sf(data.frame(coordsCast), 
                     coords = c("Easting", "Northing"), 
                     crs = 27700) 

# Transform to WGS84 (EPSG:4326)
wgs84_coords <- st_transform(bng_coords, 4326)

# Extract latitude and longitude and append to data
data$lat <- st_coordinates(wgs84_coords)[, "Y"]
data$lon <- st_coordinates(wgs84_coords)[, "X"]

# Print the head rows of the new data frame
head(data)
message('This produces a data frame that is 9 column data set') 

# Write to a csv file 
write_csv(data, 'Parks.csv')
message('These data have been written to Parks.csv')
# Out:
# [1] 1716
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=10"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=20"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=30"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=40"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=50"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=60"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=70"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=80"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=90"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/7/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=100"
#   ListEntry Name                               Grade
# 1 1000107   ROUSHAM                            I
# 2 1000108   HAMPTON COURT                      I
# 3 1000109   HIGHCLERE PARK                     I
# 4 1000110   FARNBOROUGH HALL                   I
# 5 1000111   CHISWICK HOUSE                     I
# 6 1000112   LEIGH PARK (STAUNTON COUNTRY PARK) II*
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000107
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000108
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000109
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000110
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000111
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000112
#   NGR                                          Easting Northing
# 1 SP 48283 26028, SP 47678 24234, SP4802625124 447679  224233
# 2 TQ 16570 68051                               516570  168051
# 3 SU4498459143                                 444984  159257
# 4 SP4274249465                                 443000  249084
# 5 TQ2083077489                                 520882  177637
# 6 SU 71991 08944                               471991  108944
# This produces a data frame that is 7 column data set
#   ListEntry Name                               Grade
# 1 1000107   ROUSHAM                            I
# 2 1000108   HAMPTON COURT                      I
# 3 1000109   HIGHCLERE PARK                     I
# 4 1000110   FARNBOROUGH HALL                   I
# 5 1000111   CHISWICK HOUSE                     I
# 6 1000112   LEIGH PARK (STAUNTON COUNTRY PARK) II*
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000107
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000108
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000109
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000110
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000111
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000112
#   NGR                                          Easting Northing lat
# 1 SP 48283 26028, SP 47678 24234, SP4802625124 447679  224233   51.91459
# 2 TQ 16570 68051                               516570  168051   51.39952
# 3 SU4498459143                                 444984  159257   51.33064
# 4 SP4274249465                                 443000  249084   52.13839
# 5 TQ2083077489                                 520882  177637   51.48478
# 6 SU 71991 08944                               471991  108944   50.87552
#   lon
# 1 -1.3082246
# 2 -0.3256924
# 3 -1.3557267
# 4 -1.3731311
# 5 -0.2604670
# 6 -0.9781671
# This produces a data frame that is 9 column data set
#
# These data have been written to Parks.csv

# %% [markdown]
# # Download Registered Battlefields

# %%
# Load the jsonlite library
library(jsonlite)
# Get the json response from the ARCVIEW server
# To get the parameters required read the API manual https://developers.arcgis.com/rest/services-reference/enterprise/query-feature-service/
# The id for the server is ZOdPfBS3aqqDYPUQ
# The FeatureServer layer is 8
# The dataset for NHLE points is National_Heritage_List_for_England_NHLE_v02_VIEW
countNHLEBattlefields <- fromJSON('https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/ArcGIS/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&objectIds=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&relationParam=&returnGeodetic=false&outFields=*&returnGeometry=true&returnEnvelope=false&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&defaultSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=true&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&collation=&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=200&returnZ=false&returnM=false&returnTrueCurves=true&returnExceededLimitFeatures=false&quantizationParameters=&sqlFormat=none&f=json&token=')
# Get the count
totalBattles <- countNHLEBattlefields$count[1]
# Print this value
head(totalBattles)
# We are going to get 10 records at a time
recordsToReturn <- 10
# We are going to paginate this response
pagination <- ceiling(totalParks/recordsToReturn)
# For this demo set the pagination to 10 
paginatin <- 10 
message(paste0('Pages to download: ', pagination))

# Obtain data from the ArcGIS feature server - Battlefields are layer 8
url <- paste0("https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=", recordsToReturn)
json <- fromJSON(url)
data <- json$features$attributes
# Decide which columns to keep
keeps <- c("ListEntry","Name","Grade","hyperlink","NGR","Easting","Northing","geometry")
data <- data[,(names(data) %in% keeps)]

# Now paginate through the data set
for (i in seq(from=(1 * recordsToReturn), to=(pagination*recordsToReturn), by=recordsToReturn)){
  urlDownload <- paste(url, '&resultOffset=', i, sep='')
  print(urlDownload)
  pagedJson <- fromJSON(urlDownload)
  records <- pagedJson$features$attributes
  records <- records[,(names(records) %in% keeps)]
  data <-rbind(data,records)
  # Add a snooze so we don't get blocked easily
  Sys.sleep(1.0)
}
data$Grade <- NA
head(data)

message('This produces a data frame that is 6 column data set') 

# Check if packages exist and if not install them for use
packages <- c("sf", "utils")
any_not_installed <- !all(packages %in% installed.packages()[, "Package"])
if (any_not_installed) {
  # Code to execute if at least one package is not installed
  message("At least one of the packages is not installed.")
  # Install missing packages
  missing_packages <- packages[!(packages %in% installed.packages()[, "Package"])]
  if (length(missing_packages) > 0) {
    install.packages(missing_packages)
  }
} 
library(utils)
library(sf)

# Subset the point data
pointData <- subset(data, select = c("Easting","Northing"))

## Create coordinates variable
coordsCast <- cbind(Easting = as.numeric(as.character(pointData$Easting)),
                Northing = as.numeric(as.character(pointData$Northing)))

# Create an sf object with BNG coordinates
bng_coords <- st_as_sf(data.frame(coordsCast), 
                     coords = c("Easting", "Northing"), 
                     crs = 27700) 

# Transform to WGS84 (EPSG:4326)
wgs84_coords <- st_transform(bng_coords, 4326)

# Extract latitude and longitude and append to data
data$lat <- st_coordinates(wgs84_coords)[, "Y"]
data$lon <- st_coordinates(wgs84_coords)[, "X"]

# Print the head rows of the new data frame
head(data)
message('This produces a data frame that is a 9 column data set') 

# Write to a csv file 
write_csv(data, 'Battlefields.csv')
message('These data have been written to Battlefields.csv')
# Out:
# [1] 47
# Pages to download172
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=10"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=20"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=30"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=40"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=50"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=60"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=70"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=80"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=90"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=100"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=110"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=120"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=130"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=140"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=150"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=160"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=170"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=180"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=190"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=200"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=210"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=220"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=230"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=240"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=250"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=260"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=270"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=280"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=290"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=300"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=310"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=320"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=330"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=340"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=350"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=360"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=370"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=380"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=390"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=400"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=410"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=420"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=430"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=440"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=450"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=460"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=470"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=480"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=490"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=500"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=510"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=520"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=530"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=540"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=550"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=560"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=570"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=580"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=590"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=600"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=610"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=620"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=630"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=640"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=650"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=660"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=670"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=680"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=690"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=700"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=710"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=720"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=730"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=740"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=750"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=760"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=770"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=780"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=790"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=800"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=810"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=820"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=830"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=840"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=850"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=860"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=870"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=880"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=890"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=900"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=910"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=920"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=930"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=940"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=950"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=960"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=970"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=980"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=990"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1000"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1010"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1020"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1030"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1040"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1050"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1060"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1070"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1080"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1090"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1100"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1110"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1120"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1130"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1140"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1150"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1160"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1170"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1180"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1190"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1200"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1210"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1220"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1230"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1240"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1250"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1260"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1270"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1280"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1290"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1300"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1310"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1320"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1330"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1340"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1350"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1360"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1370"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1380"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1390"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1400"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1410"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1420"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1430"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1440"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1450"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1460"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1470"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1480"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1490"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1500"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1510"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1520"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1530"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1540"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1550"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1560"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1570"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1580"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1590"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1600"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1610"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1620"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1630"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1640"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1650"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1660"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1670"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1680"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1690"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1700"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1710"
# [1] "https://services-eu1.arcgis.com/ZOdPfBS3aqqDYPUQ/arcgis/rest/services/National_Heritage_List_for_England_NHLE_v02_VIEW/FeatureServer/8/query?where=0%3D0&outFields=%2A&f=json&resultRecordCount=10&resultOffset=1720"
#   ListEntry Name
# 1 1000000   Battle of Adwalton Moor 1643
# 2 1000001   Battle of Barnet 1471
# 3 1000002   Battle of Blore Heath 1459
# 4 1000003   Battle of Boroughbridge 1322
# 5 1000004   Battle of Bosworth (Field) 1485
# 6 1000005   Battle of Braddock Down 1643
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000000
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000001
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000002
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000003
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000004
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000005
#   NGR            Easting Northing Grade
# 1 SE2164428855   421360  429026   NA
# 2 TQ 24514 97590 524514  197590   NA
# 3 SJ 71345 35300 371345  335300   NA
# 4 SE 39851 67186 439851  467186   NA
# 5 SP3947698675   439476  298925   NA
# 6 SX 17575 63008 217575   63008   NA
# This produces a data frame that is 6 column data set
#   ListEntry Name
# 1 1000000   Battle of Adwalton Moor 1643
# 2 1000001   Battle of Barnet 1471
# 3 1000002   Battle of Blore Heath 1459
# 4 1000003   Battle of Boroughbridge 1322
# 5 1000004   Battle of Bosworth (Field) 1485
# 6 1000005   Battle of Braddock Down 1643
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000000
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000001
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000002
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000003
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000004
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000005
#   NGR            Easting Northing Grade lat      lon
# 1 SE2164428855   421360  429026   NA    53.75716 -1.6775108
# 2 TQ 24514 97590 524514  197590   NA    51.66330 -0.2011212
# 3 SJ 71345 35300 371345  335300   NA    52.91435 -2.4275743
# 4 SE 39851 67186 439851  467186   NA    54.09903 -1.3921086
# 5 SP3947698675   439476  298925   NA    52.58670 -1.4187710
# 6 SX 17575 63008 217575   63008   NA    50.43850 -4.5703334
# This produces a data frame that is a 9 column data set
#
# These data have been written to Battlefields.csv

# %% [markdown]
# # Now start merging files
#
# We now want to have the merged files for all the common data to enable the next stage. This has been done for simplicity, there are other ways to do this. I wanted the person reading this to see the process. First load your data and check what it looks like with head.

# %%
# Load necessary library
library(dplyr)
# Read the CSV files
file0 <- read.csv("HAR.csv")
head(file0)
file1 <- read.csv("NHLE.csv")
head(file1)
file2 <- read.csv("Battlefields.csv")
head(file2)
file3 <- read.csv("Parks.csv")
head(file3)
file4 <- read.csv("ScheduledMonuments.csv")
head(file4)

# Set the common column, which is always ListEntry
common_column <- "ListEntry"
# Out:
#   dataset          end.date entity  entry.date
# 1 heritage-at-risk NA       7500000 2024-09-26
# 2 heritage-at-risk NA       7500001 2021-05-27
# 3 heritage-at-risk NA       7500002 2024-09-26
# 4 heritage-at-risk NA       7500003 2024-09-26
# 5 heritage-at-risk NA       7500004 2024-09-26
# 6 heritage-at-risk NA       7500005 2024-09-26
#   name
# 1 Roman fort west of Eaton House
# 2 Barlinch Priory
# 3 Roman villa 150 yards (140 metres) south east of Lea Hall
# 4 Abutment of Roman Bridge at Radnor Bridge
# 5 Defences to the Saxon town [within Bull and Kine Croft]
# 6 Rectangular enclosures 1100yds (1010m) north west of Mount Owen Farm
#   point                      ListEntry start.date typology
# 1 POINT(-2.141775 52.692762) 1006098   NA         geography
# 2 POINT(-3.529384 51.050242) 1006213   NA         geography
# 3 POINT(-2.862003 52.670884) 1006246   NA         geography
# 4 POINT(-2.703145 52.618715) 1006280   NA         geography
# 5 POINT(-1.127250 51.601647) 1006329   NA         geography
# 6 POINT(-1.542321 51.748031) 1006348   NA         geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35747
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/42043
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/41990
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/47933
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35923
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/30561
#   geography heritage.at.risk organisation
# 1 NA        NA               NA
# 2 NA        NA               NA
# 3 NA        NA               NA
# 4 NA        NA               NA
# 5 NA        NA               NA
# 6 NA        NA               NA
#   ListEntry Name                                            Grade
# 1 1021466   20 and 20A Whitbourne Springs                   II
# 2 1021467   TENNIS CORNER FARMHOUSE WITH GRANARY AND STABLE II
# 3 1021468   CHALCOT HOUSE                                   II*
# 4 1021469   FIVE LORDS FARMHOUSE                            II
# 5 1021470   PENLEIGH MILL                                   II
# 6 1021471   PENLEIGH HOUSE                                  II
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1021466
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1021467
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1021468
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1021469
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1021470
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1021471
#   NGR            Easting Northing lat      lon
# 1 ST8338544428   383389  144430   51.19884 -2.239118
# 2 ST 82839 50851 382839  150851   51.25656 -2.247300
# 3 ST 84294 48824 384294  148824   51.23838 -2.226360
# 4 ST 82772 50187 382772  150187   51.25059 -2.248227
# 5 ST 85722 50467 385722  150467   51.25319 -2.205971
# 6 ST 85622 50828 385622  150828   51.25643 -2.207419
#   ListEntry Name
# 1 1000000   Battle of Adwalton Moor 1643
# 2 1000001   Battle of Barnet 1471
# 3 1000002   Battle of Blore Heath 1459
# 4 1000003   Battle of Boroughbridge 1322
# 5 1000004   Battle of Bosworth (Field) 1485
# 6 1000005   Battle of Braddock Down 1643
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000000
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000001
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000002
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000003
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000004
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000005
#   NGR            Easting Northing grade lat      lon
# 1 SE2164428855   421360  429026   NA    53.75716 -1.6775108
# 2 TQ 24514 97590 524514  197590   NA    51.66330 -0.2011212
# 3 SJ 71345 35300 371345  335300   NA    52.91435 -2.4275743
# 4 SE 39851 67186 439851  467186   NA    54.09903 -1.3921086
# 5 SP3947698675   439476  298925   NA    52.58670 -1.4187710
# 6 SX 17575 63008 217575   63008   NA    50.43850 -4.5703334
#   ListEntry Name                               Grade
# 1 1000107   ROUSHAM                            I
# 2 1000108   HAMPTON COURT                      I
# 3 1000109   HIGHCLERE PARK                     I
# 4 1000110   FARNBOROUGH HALL                   I
# 5 1000111   CHISWICK HOUSE                     I
# 6 1000112   LEIGH PARK (STAUNTON COUNTRY PARK) II*
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000107
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000108
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000109
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000110
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000111
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000112
#   NGR                                          Easting Northing lat
# 1 SP 48283 26028, SP 47678 24234, SP4802625124 447679  224233   51.91459
# 2 TQ 16570 68051                               516570  168051   51.39952
# 3 SU4498459143                                 444984  159257   51.33064
# 4 SP4274249465                                 443000  249084   52.13839
# 5 TQ2083077489                                 520882  177637   51.48478
# 6 SU 71991 08944                               471991  108944   50.87552
#   lon
# 1 -1.3082246
# 2 -0.3256924
# 3 -1.3557267
# 4 -1.3731311
# 5 -0.2604670
# 6 -0.9781671
#   ListEntry
# 1 1001718
# 2 1001719
# 3 1001720
# 4 1001721
# 5 1001722
# 6 1001723
#   Name
# 1 Mound S of Woodbrook
# 2 Castle Twts
# 3 Lyonshall Castle
# 4 Mound 1200yds (1100m) NNE of the Church
# 5 Limebrook Priory
# 6 Two bowl barrows, one 220m east of Lower Longbeak and the other 320m east of Higher Longbeak
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1001718
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1001719
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1001720
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1001721
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1001722
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1001723
#   NGR                            Easting Northing grade lat      lon
# 1 SO 30447 54456                 330447  254456   NA    52.18395 -3.018721
# 2 SO 27703 55474                 327703  255474   NA    52.19274 -3.059066
# 3 SO 33165 56319                 333165  256319   NA    52.20103 -2.979341
# 4 SO 37237 68101                 337237  268101   NA    52.30742 -2.921963
# 5 SO 37411 66071                 337411  266071   NA    52.28919 -2.919033
# 6 SS 19954 03896, SS 19871 03235 219871  103235   NA    50.80061 -4.557574

# %% [markdown]
# Merge the National Heritage Listed Buildings with Heritage at Risk. As this is a demo, you will not get the entire dataset.

# %%
# Now start enriching by scraping
# Filter file0 and join with NHLE
common_rows_nhle <- merge(file0, file1, by = common_column) 
head(common_rows_nhle)
# Out:
#   ListEntry dataset          end.date entity  entry.date
# 1 1021635   heritage-at-risk NA       7501659 2024-09-26
#   name                            point                      start.date
# 1 Courtfield House, Polebarn Road POINT(-2.202634 51.319415) NA
#   typology
# 1 geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/327822
#   ⋯ heritage.at.risk organisation Name             Grade
# 1 ⋯ NA               NA           COURTFIELD HOUSE II*
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1021635
#   NGR            Easting Northing lat      lon
# 1 ST 85975 57832 385975  157832   51.31942 -2.202638

# %% [markdown]
# Merge the Registered Battlefields data with Heritage at risk. As this is a demo, you won't have the entire dataset.

# %%
common_rows_battlefields <- merge(file0, file2, by = common_column) 
head(common_rows_battlefields)
# Out:
#   ListEntry dataset          end.date entity  entry.date
# 1 1000000   heritage-at-risk NA       7500659 2024-09-26
# 2 1000003   heritage-at-risk NA       7500377 2024-09-26
# 3 1000025   heritage-at-risk NA       7500660 2024-09-26
#   name                    point                      start.date typology
# 1 Battle of Adwalton Moor POINT(-1.675013 53.756361) NA         geography
# 2 Battle of Boroughbridge POINT(-1.390626 54.098949) NA         geography
# 3 Battle of Newburn Ford  POINT(-1.745530 54.978350) NA         geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24508
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24509
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24542
#   ⋯ heritage.at.risk organisation Name
# 1 ⋯ NA               NA           Battle of Adwalton Moor 1643
# 2 ⋯ NA               NA           Battle of Boroughbridge 1322
# 3 ⋯ NA               NA           Battle of Newburn Ford 1640
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000000
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000003
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000025
#   NGR            Easting Northing grade lat      lon
# 1 SE2164428855   421360  429026   NA    53.75716 -1.677511
# 2 SE 39851 67186 439851  467186   NA    54.09903 -1.392109
# 3 NZ 16383 63953 416383  563953   NA    54.96993 -1.745620

# %% [markdown]
# Merge parks data with Heritage at Risk. As this is a demo, you won't have the entire dataset.

# %%
common_rows_parks <- merge(file0, file3, by = common_column) 
head(common_rows_parks)
# Out:
#   ListEntry dataset          end.date entity  entry.date name
# 1 1000124   heritage-at-risk NA       7500379 2024-09-26 Crewe Hall
# 2 1000129   heritage-at-risk NA       7500337 2024-09-26 Stoke Park
# 3 1000137   heritage-at-risk NA       7500380 2024-09-26 Thwaite Hall
# 4 1000155   heritage-at-risk NA       7500395 2024-09-26 Shrubland Hall
# 5 1000165   heritage-at-risk NA       7500351 2024-09-26 Bramshill Park
# 6 1000194   heritage-at-risk NA       7501977 2024-09-26 Wanstead Park
#   point                      start.date typology
# 1 POINT(-2.399744 53.084148) NA         geography
# 2 POINT(-2.552928 51.490522) NA         geography
# 3 POINT(-0.401842 53.780615) NA         geography
# 4 POINT(1.103647 52.133384)  NA         geography
# 5 POINT(-0.910021 51.332322) NA         geography
# 6 POINT(0.032099 51.567394)  NA         geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/26104
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/26148
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/26152
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24684
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24706
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24710
#   ⋯ heritage.at.risk organisation Name           Grade
# 1 ⋯ NA               NA           CREWE HALL     II
# 2 ⋯ NA               NA           STOKE PARK     II
# 3 ⋯ NA               NA           THWAITE HALL   II
# 4 ⋯ NA               NA           SHRUBLAND HALL I
# 5 ⋯ NA               NA           Bramshill Park I
# 6 ⋯ NA               NA           WANSTEAD PARK  II*
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000124
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000129
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000137
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000155
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000165
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000194
#   NGR            Easting Northing lat      lon
# 1 SJ7337054317   373275  353572   53.07870 -2.40039146
# 2 ST 61723 77175 361723  177175   51.49222 -2.55272411
# 3 TA 05392 32798 505392  432798   53.78085 -0.40203228
# 4 TM1181653099   612274  252889   52.13351  1.10019451
# 5 SU7626960141   476801  159656   51.33082 -0.89904043
# 6 TQ4104087270   540989  187461   51.56840  0.03285775

# %% [markdown]
# Merge scheduled monuments data.

# %%
common_rows_scheduled <- merge(file0, file4, by = common_column) 
head(common_rows_scheduled)
# Out:
#   ListEntry dataset          end.date entity  entry.date
# 1 1001731   heritage-at-risk NA       7500726 2024-09-26
# 2 1001733   heritage-at-risk NA       7500390 2021-12-01
# 3 1001735   heritage-at-risk NA       7500391 2024-09-26
# 4 1001738   heritage-at-risk NA       7500727 2024-09-26
# 5 1001747   heritage-at-risk NA       7500728 2024-09-26
# 6 1001758   heritage-at-risk NA       7500504 2024-09-26
#   name
# 1 Offa's Dyke: Rushock Hill section, extending 1630yds (1490m) east to Kennel Wood
# 2 Offa's Dyke: the section 630yds (580m) long west of Lyonshall
# 3 Offa's Dyke: section north west of Holme Marsh extending 615 yards (560 metres) to the railway
# 4 Offa's Dyke: the section extending 950yds (870m) N and S of Big Oaks
# 5 Sutton Walls (camp)
# 6 Dinedor Camp
#   point                      start.date typology
# 1 POINT(-3.032993 52.229575) NA         geography
# 2 POINT(-2.984735 52.198062) NA         geography
# 3 POINT(-2.974065 52.189224) NA         geography
# 4 POINT(-2.867624 52.083725) NA         geography
# 5 POINT(-2.694551 52.113900) NA         geography
# 6 POINT(-2.695883 52.023538) NA         geography
#   documentation.url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37764
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34594
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37756
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34587
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35712
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35701
#   ⋯ heritage.at.risk organisation
# 1 ⋯ NA               NA
# 2 ⋯ NA               NA
# 3 ⋯ NA               NA
# 4 ⋯ NA               NA
# 5 ⋯ NA               NA
# 6 ⋯ NA               NA
#   Name
# 1 Offa's Dyke: Rushock Hill section, extending 1630yds (1490m) E to Kennel Wood
# 2 Offa's Dyke: the section 630yds (580m) long W of Lyonshall
# 3 Offa's Dyke: section NW of Holme Marsh extending 615yds (560m) to the railway
# 4 Offa's Dyke: the section extending 950yds (870m) N and S of Big Oaks
# 5 Sutton Walls (camp)
# 6 Dinedor Camp
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1001731
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1001733
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1001735
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1001738
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1001747
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1001758
#   NGR                            Easting Northing grade lat      lon
# 1 SO 29562 59529                 329562  259529   NA    52.22944 -3.032720
# 2 SO 32790 55995                 332790  255995   NA    52.19807 -2.984763
# 3 SO 33493 55016                 333493  255016   NA    52.18936 -2.974287
# 4 SO 40636 43192, SO 40811 42789 340636  243192   NA    52.08388 -2.867744
# 5 SO 52520 46404                 352520  246404   NA    52.11391 -2.694778
# 6 SO 52357 36358                 352357  236358   NA    52.02358 -2.695753

# %% [markdown]
# ## Now merge the 4 files
#
# We will now merge all 4 files and write to a CSV file for reuse and scraping.

# %%
library(dplyr)
merged <- bind_rows(common_rows_scheduled, common_rows_parks, common_rows_battlefields, common_rows_nhle)
names(merged)[names(merged) == "documentation.url"] <- "url"
head(merged)
write.csv(merged, "merged_har.csv", row.names = FALSE)
# Out:
#   ListEntry dataset          end.date entity  entry.date
# 1 1001731   heritage-at-risk NA       7500726 2024-09-26
# 2 1001733   heritage-at-risk NA       7500390 2021-12-01
# 3 1001735   heritage-at-risk NA       7500391 2024-09-26
# 4 1001738   heritage-at-risk NA       7500727 2024-09-26
# 5 1001747   heritage-at-risk NA       7500728 2024-09-26
# 6 1001758   heritage-at-risk NA       7500504 2024-09-26
#   name
# 1 Offa's Dyke: Rushock Hill section, extending 1630yds (1490m) east to Kennel Wood
# 2 Offa's Dyke: the section 630yds (580m) long west of Lyonshall
# 3 Offa's Dyke: section north west of Holme Marsh extending 615 yards (560 metres) to the railway
# 4 Offa's Dyke: the section extending 950yds (870m) N and S of Big Oaks
# 5 Sutton Walls (camp)
# 6 Dinedor Camp
#   point                      start.date typology
# 1 POINT(-3.032993 52.229575) NA         geography
# 2 POINT(-2.984735 52.198062) NA         geography
# 3 POINT(-2.974065 52.189224) NA         geography
# 4 POINT(-2.867624 52.083725) NA         geography
# 5 POINT(-2.694551 52.113900) NA         geography
# 6 POINT(-2.695883 52.023538) NA         geography
#   url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37764
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34594
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37756
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34587
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35712
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35701
#   ⋯ organisation
# 1 ⋯ NA
# 2 ⋯ NA
# 3 ⋯ NA
# 4 ⋯ NA
# 5 ⋯ NA
# 6 ⋯ NA
#   Name
# 1 Offa's Dyke: Rushock Hill section, extending 1630yds (1490m) E to Kennel Wood
# 2 Offa's Dyke: the section 630yds (580m) long W of Lyonshall
# 3 Offa's Dyke: section NW of Holme Marsh extending 615yds (560m) to the railway
# 4 Offa's Dyke: the section extending 950yds (870m) N and S of Big Oaks
# 5 Sutton Walls (camp)
# 6 Dinedor Camp
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1001731
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1001733
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1001735
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1001738
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1001747
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1001758
#   NGR                            Easting Northing grade lat      lon
# 1 SO 29562 59529                 329562  259529   NA    52.22944 -3.032720
# 2 SO 32790 55995                 332790  255995   NA    52.19807 -2.984763
# 3 SO 33493 55016                 333493  255016   NA    52.18936 -2.974287
# 4 SO 40636 43192, SO 40811 42789 340636  243192   NA    52.08388 -2.867744
# 5 SO 52520 46404                 352520  246404   NA    52.11391 -2.694778
# 6 SO 52357 36358                 352357  236358   NA    52.02358 -2.695753
#   Grade
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %% [markdown]
# ## Scraping Historic England's website for enhanced data
#
# The Heritage at Risk data set that you obtain at the start has lots of missing data. These can be obtained by some simple scraping using Rvest. All the extra data is held within the HTML node with class .HARListEntry__bullets-container which will no doubt change in future when the website revamps are done. This is therefore a point in time piece of code. Some of these urls will fail as they don't seem to have a page.

# %%
# Check if packages exist and if not install them for use
packages <- c("rvest", "readr", "tidyverse", "stringr")
any_not_installed <- !all(packages %in% installed.packages()[, "Package"])
if (any_not_installed) {
  # Code to execute if at least one package is not installed
  message("At least one of the packages is not installed.")
  # Install missing packages
  missing_packages <- packages[!(packages %in% installed.packages()[, "Package"])]
  if (length(missing_packages) > 0) {
    install.packages(missing_packages)
  }
} 

library(rvest)
library(readr)
library(tidyverse)
library(stringr)

# Get the urls list from the previous CSV file created 
urls <- read.csv("merged_har.csv")
# Create an empty list to store the scraped data
scraped_data <- list()
# Loop through the list of urls.
for (i in 1:nrow(urls)) {
  url <- urls[i, 10] # Assuming the URLs are in the tenth column
  reference <-urls[i,1] # Assuming the reference number is column 1
  print(url)
  print(reference)
  # Use tryCatch to handle connection errors
  tryCatch({
    page <- read_html(url)
    css_selector <- ".HARListEntry__bullets-container" # Replace with the actual CSS selector
    
    # Extract the text content from the specified CSS selector
    #text_content <- page %>% html_nodes(css_selector) %>% html_text()
    text_content <- page %>% 
      html_nodes(css_selector) %>% 
      html_text() %>% 
      paste(collapse = " ")

    # Store the extracted data in the list
    scraped_data[[i]] <- list(url = url, text_content = text_content)
    # Remove the page object to free up memory
    rm(page)
    closeAllConnections()
    # Run garbage collection to free up memory
    gc()
  }, error = function(e) {
    # Handle the error (e.g., print a message and continue)
    message(sprintf("Failed to scrape %s: %s", url, e$message))
  })
  # Print the extracted text content
  print(text_content)
  Sys.sleep(0.5)
}
errors_df <- do.call(rbind, lapply(errors, as.data.frame))
head(scraped_data_df)
head(errors_df)
# Out:
# Failed to scrape https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34594: cannot open the connection
# Error in scraped_data[[i]]: subscript out of bounds
# Traceback:

# %% [markdown]
# There's some code here that needs removing as it breaks the text steps in the next part. I did the simplest thing possible and removed what wasn't needed - Designated Site Name.

# %%
remove_text_before_location <- function(text) {
   heritage_index <- str_locate(text, "Heritage Category:")
  if (!is.na(heritage_index[1])) { 
    return(str_sub(text, heritage_index[1])) 
  } else {
    return(text) 
  }
}

scraped_data_df <- scraped_data_df %>% 
  mutate(text_content = sapply(text_content, remove_text_before_location))
head(scraped_data_df)

# Write the scraped data to a new CSV file
write_csv(scraped_data_df, "scraped_data.csv") 
# Write the errors to a new csv file
write_csv(errors_df, "errors.csv")
# Out:
#   url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37764
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37756
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34587
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35712
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35701
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/43323
#   text_content
# 1 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001731\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Defence\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Kington Rural / Knill\r\n                Parliamentary Constituency:\r\n                    North Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Generally satisfactory but with significant localised problems\r\n                Principal Vunerability:\r\n                    Stock erosion - localised/limited\r\n                Trend:\r\n                    Improving\r\n                Ownership:\r\n                    Private\r\n
# 2 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001735\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Barrier\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Lyonshall\r\n                Parliamentary Constituency:\r\n                    North Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Generally satisfactory but with significant localised problems\r\n                Principal Vunerability:\r\n                    Development requiring planning permission \r\n                Trend:\r\n                    Declining\r\n                Ownership:\r\n                    Private, multiple owners\r\n
# 3 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001738\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Defence\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Bishopstone / Bridge Sollers / Byford\r\n                Parliamentary Constituency:\r\n                    Hereford and South Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Generally satisfactory but with minor localised problems\r\n                Principal Vunerability:\r\n                    Arable clipping \r\n                Trend:\r\n                    Declining\r\n                Ownership:\r\n                    Private\r\n
# 4 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001747\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Defence > Hillfort\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Marden / Sutton\r\n                Parliamentary Constituency:\r\n                    North Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Extensive significant problems\r\n                Principal Vunerability:\r\n                    Dumping \r\n                Trend:\r\n                    Stable\r\n                Ownership:\r\n                    Charity (heritage)\r\n
# 5 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001758\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Defence > Hillfort\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Dinedor\r\n                Parliamentary Constituency:\r\n                    Hereford and South Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Generally satisfactory but with significant localised problems\r\n                Principal Vunerability:\r\n                    Scrub/tree growth\r\n                Trend:\r\n                    Improving\r\n                Ownership:\r\n                    Other not for profit group\r\n
# 6 Heritage Category:\r\n                    Scheduled Monument\r\n                List Entry Number:\r\n                    1001778\r\n                Local Planning Authority:\r\n                    Herefordshire, County of (UA)\r\n                Site Type:\r\n                    Defence > Castle\r\n                 Unitary Authority:\r\n                    Herefordshire, County of (UA)\r\n                Parish:\r\n                    Walterstone\r\n                Parliamentary Constituency:\r\n                    Hereford and South Herefordshire\r\n                Region:\r\n                    Midlands\r\n                 Assessment Type:\r\n                    Archaeology\r\n                Condition:\r\n                    Generally unsatisfactory with major localised problems\r\n                Principal Vunerability:\r\n                    Scrub/tree growth\r\n                Trend:\r\n                    Declining\r\n                Ownership:\r\n                    Private\r\n
# Error in write_delim(x, file, delim = ",", na = na, append = append, col_names = col_names, : is.data.frame(x) is not TRUE
# Traceback:
#
# 1. write_delim(x, file, delim = ",", na = na, append = append, col_names = col_names,
#  .     quote = quote, escape = escape, eol = eol, num_threads = num_threads,
#  .     progress = progress)
# 2. stopifnot(is.data.frame(x))
# 3. stop(simpleError(msg, call = if (p <- sys.parent(1L)) sys.call(p)))

# %%
# Tidyverse was installed previously. 
library(tidyverse)

# Read the CSV file
df <- read_csv('scraped_data.csv')

# Function to split text_content into key-value pairs
split_text_content <- function(text) {
  lines <- str_split(text, "\n")[[1]]
  data <- list()
  key <- NULL
  for (line in lines) {
    if (str_detect(line, ":")) {
      parts <- str_split(line, ":", n = 2)[[1]]
      key <- str_trim(parts[1])
      value <- str_trim(parts[2])
      data[[key]] <- value
    } else if (!is.null(key)) {
      data[[key]] <- paste(data[[key]], str_trim(line))
    }
  }
  return(data)
}

# Apply the function to the text_content column
split_data <- map(df$text_content, split_text_content)

# Create a new data frame from the split data
split_df <- bind_rows(split_data)

# Combine the original URL column with the new data frame
result_df <- bind_cols(df %>% select(url), split_df)
head(result_df)
# Write the result to a new CSV file
write_csv(result_df, 'processed_scraped_data.csv')
# Out:
# Rows: 22 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# chr (2): url, text_content
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37764
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/37756
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/34587
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35712
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/35701
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/43323
#   Heritage Category   List Entry Number Local Planning Authority
# 1  Scheduled Monument  1001731           Herefordshire, County of (UA)
# 2  Scheduled Monument  1001735           Herefordshire, County of (UA)
# 3  Scheduled Monument  1001738           Herefordshire, County of (UA)
# 4  Scheduled Monument  1001747           Herefordshire, County of (UA)
# 5  Scheduled Monument  1001758           Herefordshire, County of (UA)
# 6  Scheduled Monument  1001778           Herefordshire, County of (UA)
#   Site Type           Unitary Authority
# 1  Defence             Herefordshire, County of (UA)
# 2  Barrier             Herefordshire, County of (UA)
# 3  Defence             Herefordshire, County of (UA)
# 4  Defence > Hillfort  Herefordshire, County of (UA)
# 5  Defence > Hillfort  Herefordshire, County of (UA)
# 6  Defence > Castle    Herefordshire, County of (UA)
#   Parish                                 Parliamentary Constituency
# 1  Kington Rural / Knill                  North Herefordshire
# 2  Lyonshall                              North Herefordshire
# 3  Bishopstone / Bridge Sollers / Byford  Hereford and South Herefordshire
# 4  Marden / Sutton                        North Herefordshire
# 5  Dinedor                                Hereford and South Herefordshire
# 6  Walterstone                            Hereford and South Herefordshire
#   Region    Assessment Type ⋯ Street Name Locality County District / Borough
# 1  Midlands  Archaeology    ⋯ NA          NA       NA     NA
# 2  Midlands  Archaeology    ⋯ NA          NA       NA     NA
# 3  Midlands  Archaeology    ⋯ NA          NA       NA     NA
# 4  Midlands  Archaeology    ⋯ NA          NA       NA     NA
# 5  Midlands  Archaeology    ⋯ NA          NA       NA     NA
# 6  Midlands  Archaeology    ⋯ NA          NA       NA     NA
#   Occupancy / Use Priority Previous Priority Designation List Entry Number(s)
# 1 NA              NA       NA                NA          NA
# 2 NA              NA       NA                NA          NA
# 3 NA              NA       NA                NA          NA
# 4 NA              NA       NA                NA          NA
# 5 NA              NA       NA                NA          NA
# 6 NA              NA       NA                NA          NA
#   Vulnerability
# 1 NA
# 2 NA
# 3 NA
# 4 NA
# 5 NA
# 6 NA

# %%
# Load necessary library
library(dplyr)

# Read the CSV files
file1 <- read.csv("processed_scraped_data.csv")
file2 <- read.csv("merged_har.csv")
common_column <- "url" # Replace with the actual column name

# Find common rows based on the common column
common_rows <- merge(file1, file2, by = common_column)


# Print the common rows
head(common_rows)
write_csv(common_rows, 'openrefineHAR.csv')
# Out:
#   url
# 1 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24508
# 2 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24509
# 3 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24542
# 4 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24684
# 5 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24706
# 6 https://historicengland.org.uk/advice/heritage-at-risk/search-register/list-entry/24710
#   Heritage.Category                     List.Entry.Number
# 1  Registered Battlefield               1000000
# 2  Registered Battlefield               1000003
# 3  Registered Battlefield               1000025
# 4  Registered Park and Garden grade I   1000155
# 5  Registered Park and Garden grade I   1000165
# 6  Registered Park and Garden grade II* 1000194
#   Local.Planning.Authority
# 1  Bradford
# 2  North Yorkshire Council (UA)
# 3  Newcastle upon Tyne
# 4  Mid Suffolk
# 5  Hart
# 6  Redbridge
#   Site.Type
# 1  Battlefield
# 2  Battlefield
# 3  Battlefield
# 4  Gardens parks and urban spaces > Landscape park
# 5  Gardens parks and urban spaces > Landscape park
# 6  Gardens parks and urban spaces > Park
#   Unitary.Authority             Parish
# 1 NA                             Drighlington
# 2  North Yorkshire Council (UA)  Boroughbridge / Langthorpe / Milby
# 3 NA                            NA
# 4 NA                             Hemingstone / Barham / Coddenham
# 5 NA                             Mattingley / Bramshill / Eversley
# 6 NA                            NA
#   Parliamentary.Constituency                    Region
# 1  Leeds South West and Morley / Bradford South  North East and Yorkshire
# 2  Wetherby and Easingwold                       North East and Yorkshire
# 3  Blaydon and Consett / Hexham                  North East and Yorkshire
# 4  Central Suffolk and North Ipswich             East of England
# 5  North East Hampshire                          London and South East
# 6  Leyton and Wanstead                           London and South East
#   Assessment.Type  ⋯ organisation Name
# 1  Battlefield     ⋯ NA           Battle of Adwalton Moor 1643
# 2  Battlefield     ⋯ NA           Battle of Boroughbridge 1322
# 3  Battlefield     ⋯ NA           Battle of Newburn Ford 1640
# 4  Park and garden ⋯ NA           SHRUBLAND HALL
# 5  Park and garden ⋯ NA           Bramshill Park
# 6  Park and garden ⋯ NA           WANSTEAD PARK
#   hyperlink
# 1 https://historicengland.org.uk/listing/the-list/list-entry/1000000
# 2 https://historicengland.org.uk/listing/the-list/list-entry/1000003
# 3 https://historicengland.org.uk/listing/the-list/list-entry/1000025
# 4 https://historicengland.org.uk/listing/the-list/list-entry/1000155
# 5 https://historicengland.org.uk/listing/the-list/list-entry/1000165
# 6 https://historicengland.org.uk/listing/the-list/list-entry/1000194
#   NGR            Easting Northing grade lat      lon         Grade
# 1 SE2164428855   421360  429026   NA    53.75716 -1.67751079 NA
# 2 SE 39851 67186 439851  467186   NA    54.09903 -1.39210863 NA
# 3 NZ 16383 63953 416383  563953   NA    54.96993 -1.74561992 NA
# 4 TM1181653099   612274  252889   NA    52.13351  1.10019451 I
# 5 SU7626960141   476801  159656   NA    51.33082 -0.89904043 I
# 6 TQ4104087270   540989  187461   NA    51.56840  0.03285775 II*
